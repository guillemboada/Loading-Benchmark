# %% [markdown]
# # Benchmark of loading dataset approaches in TensorFlow
#
# This notebook benchmarks four different approaches to input a dataset to fit a model using TensorFlow. While it is possible to do it with a custom generator, the `tf.data` API offers possibilities which may be more confortable and even more efficient. Here the tested approaches:
#
# * **a)** Using `.from_tensor_slices()`
# * **b)** Using `.from_generator()`
# * **c)** Using `.flow_from_directory()`
# * **d)** Using `.tfrecords`
#
# Let's start by importing the required packages and the configuration stored in `parameters.ini`.

# %%
import os
import sys
import subprocess
import numpy as np
import matplotlib.pyplot as plt
import wandb
os.environ["WANDB_NOTEBOOK_NAME"] = os.path.join(os.getcwd(), "LoadingBenchmark.ipynb")
import utils
import tensorflow_datasets as tfds
from IPython.display import clear_output
import configparser

config = configparser.ConfigParser()
config.read('parameters.ini')
N = int(config['DEFAULT']['n'])
HEIGHT = int(config['DEFAULT']['height'])
WIDTH = int(config['DEFAULT']['width'])
BATCH_SIZE = int(config['DEFAULT']['batch_size'])
BUFFER_SIZE = int(config['DEFAULT']['buffer_size'])
EPOCHS = int(config['DEFAULT']['epochs'])
WANDB_ENTITY_NAME = config['DEFAULT']['wandb_entity_name']
WANDB_PROJECT_NAME = config['DEFAULT']['wandb_project_name']
STEPS = N // BATCH_SIZE

DATA_PATH = os.path.join(os.getcwd(), "Data")

# %% [markdown]
# ### Download toy data

# %% [markdown]
# To benchmark the dataset creation approaches, we need a task to solve, a toy dataset and a model to train. We will solve a segmentation task on the [Oxford-IIIT Pet Dataset](https://www.robots.ox.ac.uk/~vgg/data/pets/) ([Parkhi et al, 2012](https://www.robots.ox.ac.uk/~vgg/publications/2012/parkhi12a/parkhi12a.pdf)) with the UNet-like model provided in the [Image Segmentation TensorFlow tutorial](https://www.tensorflow.org/tutorials/images/segmentation). The next line of code downloads the dataset and structures it as follows in the determined `project` directory indicated with the variable `DATA_PATH`, defined in `parameters.ini`. It may take about 5 minutes.
# ```
# {DATA_PATH}
# |
# └───images
# │   |   image001.png
# │   |   image002.png
# │   |   ...
# |
# └───masks
#     │   mask001.png
#     │   mask002.png
#     |   ...
# ```

# %%
if not os.path.exists(DATA_PATH):
    os.mkdir(DATA_PATH)

utils.download_data(DATA_PATH)
# Out:
# Data is already in indicated path: ..\Data

# %% [markdown]
# ### Create TensorFlow datasets with different approaches

# %% [markdown]
# ##### **a)** Using `.from_tensor_slices()`

# %%
from DatasetLoadingApproaches import using_from_tensor_slices
dataset_a = using_from_tensor_slices.get_dataset(DATA_PATH, BATCH_SIZE, BUFFER_SIZE)

for batch in dataset_a.take(1):
    sample_image = batch[0][0]
    sample_mask = batch[1][0]
    plt.subplot(1,2,1); plt.imshow(sample_image)
    plt.subplot(1,2,2); plt.imshow(sample_mask)

# %% [markdown]
# ##### **b)** Using `.from_generator()`

# %%
from DatasetLoadingApproaches import using_from_generator

# From paths
generator_b_from_paths = using_from_generator.get_generator_from_paths(DATA_PATH, BATCH_SIZE)
dataset_b_from_paths = using_from_generator.get_dataset_from_paths(DATA_PATH, BATCH_SIZE)

# From preloaded data (kind of a manual cache). It should be faster because data is already in the RAM during training and does not need to be loaded at every epoch
images_paths, masks_paths = using_from_generator.get_data_paths(DATA_PATH)
preloaded_images = using_from_generator.load_samples(images_paths, "images", verbose=1)
preloaded_masks = using_from_generator.load_samples(masks_paths, "masks", verbose=1)
generator_b_from_preloaded_data = using_from_generator.get_generator_from_preloaded_data(preloaded_images, preloaded_masks, BATCH_SIZE)
dataset_b_from_preloaded_data = using_from_generator.get_generator_from_preloaded_data(preloaded_images, preloaded_masks, BATCH_SIZE)

# Form semi-preloaded data, i.e., in uint8 while we really need it in float32 for the fit(). The dataset requires a map().
# This is smart because uint8 take much less space so they may fit into the RAM.
images_paths, masks_paths = using_from_generator.get_data_paths(DATA_PATH)
semipreloaded_images = using_from_generator.load_samples(images_paths, "images", preprocess=False, verbose=1)
semipreloaded_masks = using_from_generator.load_samples(masks_paths, "masks", preprocess=False, verbose=1)
generator_b_semipreloaded = using_from_generator.get_generator_from_preloaded_data(semipreloaded_images, semipreloaded_masks, BATCH_SIZE, semipreloaded=True)
dataset_b_semipreloaded = using_from_generator.get_dataset_from_preloaded_data(semipreloaded_images, semipreloaded_masks, BATCH_SIZE, semipreloaded=True)

for batch in dataset_b_from_paths.take(1):
    sample_image = batch[0][0]
    sample_mask = batch[1][0]
    plt.subplot(1,2,1); plt.imshow(sample_image)
    plt.subplot(1,2,2); plt.imshow(sample_mask)
# Out:
# 100%|██████████| 7384/7384 [00:28<00:00, 256.52it/s]
# 100%|██████████| 7384/7384 [00:05<00:00, 1258.56it/s]
# 100%|██████████| 7384/7384 [00:24<00:00, 303.36it/s]
# 100%|██████████| 7384/7384 [00:04<00:00, 1608.20it/s]

# %% [markdown]
# ##### **c)** Using `.flow_from_directory()`

# %% [markdown]
# For this approach, we need to structure out data in subdirectories.

# %%
utils.structure_data_in_subdirectories(DATA_PATH)
# Out:
# Data is already in paths: ..\directory_images, ..\directory_masks

# %% [markdown]
# Create dataset

# %%
from DatasetLoadingApproaches import using_flow_from_directory

directory_images_path = os.path.join(DATA_PATH, "directory_images")
directory_masks_path = os.path.join(DATA_PATH, "directory_masks")
generator_c = using_flow_from_directory.get_generator(directory_images_path, directory_masks_path, BATCH_SIZE)
dataset_c = using_flow_from_directory.get_dataset(directory_images_path, directory_masks_path, BATCH_SIZE)

for batch in dataset_c.take(1):
    sample_image = batch[0][0]
    sample_mask = batch[1][0]
    plt.subplot(1,2,1)
    plt.imshow(sample_image)
    plt.subplot(1,2,2)
    plt.imshow(sample_mask)

# %% [markdown]
# ##### **d)** Using `.tfrecords`

# %% [markdown]
# Create TFRECORDS files

# %%
from DatasetLoadingApproaches import tfrecords_creation

MAX_FILES = 15

tfrecords_path = os.path.join(DATA_PATH, "TFRecords")
if os.path.isdir(tfrecords_path):
    print(f"TFRECORDS files are already in path: ..\{os.path.basename(tfrecords_path)}")
else:
    if not os.path.isdir(tfrecords_path):
        os.mkdir(tfrecords_path)
    tfrecords_creation.dynamic_write_images_to_tfr(DATA_PATH, MAX_FILES, tfrecords_path, filename="animals_float32", preprocess=True)
# Out:
# TFRECORDS files are already in path: ..\TFRecords

# %% [markdown]
# Create dataset

# %%
from DatasetLoadingApproaches import using_tfrecords

tfrecords_path = os.path.join(DATA_PATH, "TFRecords")
dataset_d_float = using_tfrecords.get_dataset(tfrecords_path, "animals_float32*.tfrecords", BATCH_SIZE, BUFFER_SIZE)
dataset_d_uint = using_tfrecords.get_dataset(tfrecords_path, "animals_uint8*.tfrecords", BATCH_SIZE, BUFFER_SIZE, mapping=using_tfrecords.map_from_uint_to_float)

for batch in dataset_d_uint.take(1):
    sample_image = batch[0][0]
    sample_mask = batch[1][0]
    plt.subplot(1,2,1)
    plt.imshow(sample_image)
    plt.subplot(1,2,2)
    plt.imshow(sample_mask)

# %% [markdown]
# ### Benchmark datasets delivery speed

# %%
datasets = [dataset_a, generator_b_from_paths, dataset_b_from_paths, generator_b_from_preloaded_data, dataset_b_from_preloaded_data, generator_b_semipreloaded, dataset_b_semipreloaded, dataset_c, dataset_d_float, dataset_d_uint]
run_names = ["Using .from_tensor_slices()", "Using simple generator", "Using .from_generator()", "Using simple generator with preloaded data", "Using .from_generator() with preloaded data", "Using simple generator with semipreloaded data", "Using .from_generator() with semipreloaded data", "Using .flow_from_directory()", "Using .tfrecords (float)", "Using .tfrecords (uint)"]

# Benchmark dataset delivery speeds
NUM_ITER = N
all_statistics = []
for run_name,dataset in zip(run_names, datasets):
    all_statistics.append(tfds.benchmark(dataset, num_iter=NUM_ITER, batch_size=BATCH_SIZE))
    clear_output()

# Preprocess runtimes for plotting
examples_per_seconds = [statistics.stats.avg[0] for statistics in all_statistics]
order_idxs = np.argsort(examples_per_seconds)[::-1]
ordered_run_names = np.array(run_names)[order_idxs]
ordered_examples_per_seconds = np.array(examples_per_seconds)[order_idxs]

# Visualize
fig, ax = plt.subplots(figsize=(12,5))
y_pos = np.arange(len(ordered_run_names))
ax.barh(y_pos, ordered_examples_per_seconds, align='center')
ax.set_yticks(y_pos, labels=ordered_run_names)
ax.invert_yaxis()
ax.set_xlabel('Time (minutes)')
ax.set_title(f'Dataset delivery times')
ax.set_axisbelow(True)
ax.grid()
plt.gcf().subplots_adjust(left=0.4)
plt.show()

print(f"TOP DATASET DELIVERY SPEEDS:")
for run_name, run_time in zip(ordered_run_names, ordered_examples_per_seconds):
    print(f"{run_time/EPOCHS:.2f} samples / second -", run_name)
# Out:
# TOP DATASET DELIVERY SPEEDS:
# 49.49 examples / second - .from_generator() with preloaded data
# 48.01 examples / second - simple generator with preloaded data
# 35.91 examples / second - .tfrecords (uint)
# 31.65 examples / second - simple generator with semipreloaded data
# 26.63 examples / second - .from_generator() with semipreloaded data
# 16.34 examples / second - .tfrecords (float)
# 3.48 examples / second - .flow_from_directory()
# 2.63 examples / second - simple generator
# 2.63 examples / second - .from_generator()
# 2.54 examples / second - .from_tensor_slices()

# %% [markdown]
# ### Benchmark training performance

# %% [markdown]
# Define model

# %%
site_packages_path = f"{sys.prefix}/lib/site-packages"
if "tensorflow_examples" not in os.listdir(site_packages_path):
    subprocess.check_call(["pip", "install", "git+https://github.com/tensorflow/examples.git"])

from segmentation_model import unet_model
model = unet_model(output_channels=3)
# Out:
# Segmentation Models: using `tf.keras` framework.

# %% [markdown]
# Train model with different dataset creation approaches

# %%
for run_name,dataset in zip(run_names, datasets):
    print(run_name)
    wandb.init(project=WANDB_PROJECT_NAME, entity=WANDB_ENTITY_NAME, name=run_name + f" [{EPOCHS} epochs]")
    model.fit(dataset, epochs=EPOCHS, steps_per_epoch=STEPS, callbacks=[utils.MonitorCallback()])
    wandb.finish()
# Out:
# Using .from_generator() with semipreloaded data
# wandb: W&B API key is configured (use `wandb login --relogin` to force relogin)
# wandb: Network error (ConnectionError), entering retry loop.
#                     Syncing run <strong><a href="http://localhost:8080/boadagu/DatasetLoadingBenchmark/runs/11n2ul18" target="_blank">Using .from_generator() with semipreloaded data [100 epochs]</a></strong> to <a href="http://localhost:8080/boadagu/DatasetLoadingBenchmark" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# Epoch 1/100
# 115/923 [==>...........................] - ETA: 29s - loss: 0.3834 - accuracy: 0.8543
# wandb: Network error resolved after 0:00:16.639843, resuming normal operation.
# 923/923 [==============================] - 34s 37ms/step - loss: 0.3298 - accuracy: 0.8751
# Epoch 2/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.2843 - accuracy: 0.8919
# Epoch 3/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.2671 - accuracy: 0.8982
# Epoch 4/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.2569 - accuracy: 0.9016
# Epoch 5/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.2489 - accuracy: 0.9047
# Epoch 6/100
# 923/923 [==============================] - 33s 35ms/step - loss: 0.2387 - accuracy: 0.9081
# Epoch 7/100
# 923/923 [==============================] - 33s 35ms/step - loss: 0.2306 - accuracy: 0.9108
# Epoch 8/100
# 923/923 [==============================] - 33s 36ms/step - loss: 0.2228 - accuracy: 0.9137
# Epoch 9/100
# 923/923 [==============================] - 33s 36ms/step - loss: 0.2135 - accuracy: 0.9170
# Epoch 10/100
# 923/923 [==============================] - 34s 37ms/step - loss: 0.2062 - accuracy: 0.9196
# Epoch 11/100
# 923/923 [==============================] - 33s 36ms/step - loss: 0.1967 - accuracy: 0.9229
# Epoch 12/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.1875 - accuracy: 0.9263
# Epoch 13/100
# 923/923 [==============================] - 33s 36ms/step - loss: 0.1789 - accuracy: 0.9294
# Epoch 14/100
# 923/923 [==============================] - 33s 36ms/step - loss: 0.1702 - accuracy: 0.9327
# Epoch 15/100
# 923/923 [==============================] - 33s 36ms/step - loss: 0.1638 - accuracy: 0.9352
# Epoch 16/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.1557 - accuracy: 0.9383
# Epoch 17/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.1493 - accuracy: 0.9408
# Epoch 18/100
# 923/923 [==============================] - 33s 35ms/step - loss: 0.1442 - accuracy: 0.9429
# Epoch 19/100
# 923/923 [==============================] - 33s 36ms/step - loss: 0.1389 - accuracy: 0.9450
# Epoch 20/100
# 923/923 [==============================] - 31s 34ms/step - loss: 0.1337 - accuracy: 0.9472
# Epoch 21/100
# 923/923 [==============================] - 31s 34ms/step - loss: 0.1275 - accuracy: 0.9496
# Epoch 22/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.1247 - accuracy: 0.9508
# Epoch 23/100
# 923/923 [==============================] - 31s 34ms/step - loss: 0.1194 - accuracy: 0.9530
# Epoch 24/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.1153 - accuracy: 0.9546
# Epoch 25/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.1124 - accuracy: 0.9558
# Epoch 26/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.1097 - accuracy: 0.9570
# Epoch 27/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.1070 - accuracy: 0.9582
# Epoch 28/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.1029 - accuracy: 0.9598
# Epoch 29/100
# 923/923 [==============================] - 31s 34ms/step - loss: 0.1004 - accuracy: 0.9608
# Epoch 30/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.0987 - accuracy: 0.9615
# Epoch 31/100
# 923/923 [==============================] - 31s 34ms/step - loss: 0.0953 - accuracy: 0.9629
# Epoch 32/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.0937 - accuracy: 0.9636
# Epoch 33/100
# 923/923 [==============================] - 31s 34ms/step - loss: 0.0914 - accuracy: 0.96450s - loss: 0.0914 - accu
# Epoch 34/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.0892 - accuracy: 0.9654
# Epoch 35/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0876 - accuracy: 0.9660
# Epoch 36/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.0861 - accuracy: 0.9667
# Epoch 37/100
# 923/923 [==============================] - 31s 34ms/step - loss: 0.0849 - accuracy: 0.9672
# Epoch 38/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.0823 - accuracy: 0.9682
# Epoch 39/100
# 923/923 [==============================] - 31s 34ms/step - loss: 0.0809 - accuracy: 0.9688
# Epoch 40/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0797 - accuracy: 0.9693
# Epoch 41/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0783 - accuracy: 0.9698
# Epoch 42/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0773 - accuracy: 0.9702
# Epoch 43/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0761 - accuracy: 0.9707
# Epoch 44/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0752 - accuracy: 0.9711
# Epoch 45/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0734 - accuracy: 0.9718
# Epoch 46/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0729 - accuracy: 0.9720
# Epoch 47/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.0719 - accuracy: 0.9724
# Epoch 48/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0706 - accuracy: 0.9729
# Epoch 49/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.0711 - accuracy: 0.97271s - loss: 0.0711 - accura - ETA:
# Epoch 50/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0688 - accuracy: 0.9737
# Epoch 51/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0683 - accuracy: 0.9738
# Epoch 52/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0672 - accuracy: 0.9743
# Epoch 53/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0668 - accuracy: 0.9744
# Epoch 54/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0659 - accuracy: 0.97480s - loss: 0.0658 - accu
# Epoch 55/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0653 - accuracy: 0.9750
# Epoch 56/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0643 - accuracy: 0.9754
# Epoch 57/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.0639 - accuracy: 0.9756
# Epoch 58/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0633 - accuracy: 0.9758
# Epoch 59/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0621 - accuracy: 0.9763
# Epoch 60/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0619 - accuracy: 0.9764
# Epoch 61/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0609 - accuracy: 0.9768
# Epoch 62/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0618 - accuracy: 0.9764
# Epoch 63/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.0601 - accuracy: 0.9771
# Epoch 64/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0592 - accuracy: 0.9774
# Epoch 65/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0589 - accuracy: 0.9775
# Epoch 66/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.0589 - accuracy: 0.9776
# Epoch 67/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0587 - accuracy: 0.9776
# Epoch 68/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.0575 - accuracy: 0.9781
# Epoch 69/100
# 923/923 [==============================] - 31s 34ms/step - loss: 0.0567 - accuracy: 0.9784
# Epoch 70/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.0567 - accuracy: 0.9784
# Epoch 71/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0561 - accuracy: 0.9786
# Epoch 72/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.0559 - accuracy: 0.9787
# Epoch 73/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0549 - accuracy: 0.9791
# Epoch 74/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.0548 - accuracy: 0.9791
# Epoch 75/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0547 - accuracy: 0.9792
# Epoch 76/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.0541 - accuracy: 0.9794
# Epoch 77/100
# 923/923 [==============================] - 31s 34ms/step - loss: 0.0538 - accuracy: 0.9795
# Epoch 78/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.0537 - accuracy: 0.9796
# Epoch 79/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0530 - accuracy: 0.9798
# Epoch 80/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.0524 - accuracy: 0.9801
# Epoch 81/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0521 - accuracy: 0.9802
# Epoch 82/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.0523 - accuracy: 0.9801
# Epoch 83/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0517 - accuracy: 0.9803
# Epoch 84/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.0513 - accuracy: 0.9805
# Epoch 85/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.0510 - accuracy: 0.9806
# Epoch 86/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.0504 - accuracy: 0.9808
# Epoch 87/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0508 - accuracy: 0.9807
# Epoch 88/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.0498 - accuracy: 0.9811
# Epoch 89/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0495 - accuracy: 0.9812
# Epoch 90/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.0494 - accuracy: 0.9812
# Epoch 91/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0492 - accuracy: 0.9813
# Epoch 92/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.0490 - accuracy: 0.9814
# Epoch 93/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0490 - accuracy: 0.9814
# Epoch 94/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.0484 - accuracy: 0.9816
# Epoch 95/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0478 - accuracy: 0.9819
# Epoch 96/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.0476 - accuracy: 0.9819
# Epoch 97/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.0475 - accuracy: 0.9820
# Epoch 98/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.0472 - accuracy: 0.9821
# Epoch 99/100
# 923/923 [==============================] - 32s 35ms/step - loss: 0.0470 - accuracy: 0.9821
# Epoch 100/100
# 923/923 [==============================] - 32s 34ms/step - loss: 0.0471 - accuracy: 0.9821
# <br/>Waiting for W&B process to finish, PID 16804... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>RAM (%)</td><td>▁▂▃▄▅▆▇█▇▂▂▂▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃</td></tr><tr><td>RAM (MB)</td><td>▁▂▃▄▅▆▇█▇▂▂▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃</td></tr><tr><td>VRAM (MB) from smi</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>VRAM (MB) from tf</td><td>▃▁▂▅▂▅▅▅▂▄▄▅▂▇▄▂▅▆▆█▄▂▇▁▄▅▄▄▅▅▁▇▂▄█▂▁▁▂▃</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>RAM (%)</td><td>52.7</td></tr><tr><td>RAM (MB)</td><td>17131.39062</td></tr><tr><td>VRAM (MB) from smi</td><td>5843.71405</td></tr><tr><td>VRAM (MB) from tf</td><td>67.11963</td></tr></table>
# </div></div>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# <br/>Synced <strong style="color:#cdcd00">Using .from_generator() with semipreloaded data [100 epochs]</strong>: <a href="http://localhost:8080/boadagu/DatasetLoadingBenchmark/runs/11n2ul18" target="_blank">http://localhost:8080/boadagu/DatasetLoadingBenchmark/runs/11n2ul18</a><br/>
# Find logs at: <code>.\wandb\run-20220103_112919-11n2ul18\logs</code><br/>

# %% [markdown]
# ### Results

# %%
# Import runtimes from W&B 
api = wandb.Api()
runs_dict = {}
for run in api.runs(path=f"{WANDB_ENTITY_NAME}/{WANDB_PROJECT_NAME}", filters={"display_name": {"$regex": ".*\[100 epochs\]"}}):
    runs_dict[run.name] = run.summary.get('_wandb')['runtime']

# Preprocess runtimes for plotting
run_times_in_seconds = [runs_dict[run_name + " [100 epochs]"] for run_name in run_names]
order_idxs = np.argsort(run_times_in_seconds)[::-1]
ordered_run_names = [run_name[6:] for run_name in np.array(run_names)[order_idxs]]
ordered_run_times_in_minutes = np.array(run_times_in_seconds)[order_idxs] / 60

# Visualize
SAVE_PLOT = True
fig, ax = plt.subplots(figsize=(12,5))
y_pos = np.arange(len(ordered_run_names))
ax.barh(y_pos, ordered_run_times_in_minutes, align='center')
ax.set_yticks(y_pos, labels=ordered_run_names)
ax.invert_yaxis()
ax.set_xlabel('Time (minutes)')
ax.set_title(f'Training times for {EPOCHS} epochs')
ax.set_axisbelow(True)
ax.grid()
plt.gcf().subplots_adjust(left=0.4)
plt.show()

if SAVE_PLOT:
    fig.savefig(os.path.join(os.getcwd(), "TrainingTimes.png"), dpi=fig.dpi)

print(f"TOP TRAINING TIMES:")
for run_name, run_time in zip(ordered_run_names[::-1], ordered_run_times_in_minutes[::-1]):
    print(f"{run_time/EPOCHS:.2f} minutes / epoch -", run_name)
# Out:
# TOP TRAINING TIMES:
# 0.49 minutes / epoch - .tfrecords (uint)
# 0.50 minutes / epoch - .tfrecords (float)
# 0.52 minutes / epoch - simple generator with preloaded data
# 0.53 minutes / epoch - .from_generator() with semipreloaded data
# 0.54 minutes / epoch - simple generator with semipreloaded data
# 0.57 minutes / epoch - .from_generator() with preloaded data
# 1.84 minutes / epoch - .flow_from_directory()
# 2.80 minutes / epoch - .from_generator()
# 3.22 minutes / epoch - simple generator
# 3.22 minutes / epoch - .from_tensor_slices()

# %% [markdown]
# ### Conclusions

# %% [markdown]
# Using **TFRECORDS** is the fastest approach (~ 30 seconds / epoch) followed by the **preloaded and semipreloaded datasets**, which do not seem to show any significant difference between them. These methods require a priori computation expense: for the used animals dataset (7384 samples resized to 128x128), TFRECORDS files are created in ~ 27 seconds and data is preloaded in ~ 25 seconds. The difference is minimal. However, if the training run with a particular dataset is planned to be executed multiple times, using TFRECORDS is a better choice because they only need to be created once, against preloading the data, which needs to be done every time and must fit in the RAM. Moreover, this preloading will take GPU compute time if being run on a cloud service, which is more expensive than CPU compute time. The drawbacks of TFRECORDS are that they take storage space, are less transparent (because of binarization) and require an additional overhead for parsing and unparsing them.
#
# <!-- **SUMMARY:**
#
# &nbsp;&nbsp;**TFRECORDS dataset**
# &nbsp;&nbsp;&nbsp;&nbsp;\+ Only needs to be done once
# &nbsp;&nbsp;&nbsp;&nbsp;\- Less transparent (because of binarization)
# &nbsp;&nbsp;&nbsp;&nbsp;\- Take up additional storage space
# &nbsp;&nbsp;&nbsp;&nbsp;\- Additional overhead to parse and unparse TFRECORDS
# &nbsp;&nbsp;**preloaded and semipreloaded datasets**
# &nbsp;&nbsp;&nbsp;&nbsp;\+ Transparent because samples can be read straight-away
# &nbsp;&nbsp;&nbsp;&nbsp;\- Needs to be done at each training run
# &nbsp;&nbsp;&nbsp;&nbsp;\- Uses GPU compute time, i.e., more expensive
# &nbsp;&nbsp;&nbsp;&nbsp;\- Requires a big enough RAM to fit the preloaded data  -->
